# %%
# IMPORT TOOLS
import sys
import subprocess
sys.path.insert(1, f"{subprocess.Popen(['git', 'rev-parse', '--show-toplevel'], stdout=subprocess.PIPE).communicate()[0].rstrip().decode('utf-8')}/logistics/tools")
from image_to_thesis import ThesisSection, save, pull_from_thesis
pull_from_thesis()
# ------------
# Out:
# pull_from_thesis: Pulling from master-thesis repository
# pull_from_thesis: Done

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(np.linspace(0, 1, 100), np.linspace(0, 1, 100), '*g')
plt.title("banan")
plt.xlabel("banan2")
plt.ylabel("banan23123123213")
save(plt, ThesisSection.THEORY, "cross_section_test2.png")
save(plt, ThesisSection.THEORY, "test/cross_section_test2.png")

plt.show()
# Out:
# save: Saving cross_section_test2.png to theory
# pull_from_thesis: Pulling from master-thesis repository
# pull_from_thesis: Done
# push_to_thesis: Pushing to master-thesis repository
# push_to_thesis: Done
# save: Saving test/cross_section_test2.png to theory
# pull_from_thesis: Pulling from master-thesis repository
# pull_from_thesis: Done
# push_to_thesis: Pushing to master-thesis repository
# push_to_thesis: Done
