# %%
# IMPORT TOOLS
import sys
import subprocess
sys.path.insert(1, f"{subprocess.Popen(['git', 'rev-parse', '--show-toplevel'], stdout=subprocess.PIPE).communicate()[0].rstrip().decode('utf-8')}/logistics/tools")
from image_to_thesis import section_img_dir, ThesisSection, push_to_thesis
# ------------

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(np.linspace(0, 1, 100), np.linspace(0, 1, 100))
plt.show()
plt.savefig(f"{section_img_dir(ThesisSection.THEORY)}/cross_section_test.png")
push_to_thesis()
# Out:
# push_to_thesis: Pushing to master-thesis repository
# push_to_thesis: Done
